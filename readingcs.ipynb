# %% [markdown]
# # Lecture de l'emploi du temps avec Pandas

# %%
import pandas as pd

# Read the data
data = pd.read_csv('27/02-03/03.csv', delimiter=';')
# Print all columns
print(data.columns)
# Out:
# Index(['LUNDI', 'MARDI', 'MERCREDI', 'JEUDI', 'VENDREDI', 'Unnamed: 5'], dtype='object')

# %% [markdown]
# ## Lecture des jours de la semaine

# %%
# lecture simple
data[["MARDI"]]
# Out:
#                                                 MARDI
# 0                                             28-févr
# 1                                            8h-12h15
# 2                          CONCEP.LOGICIELLE/BIG DATA
# 3                                    Bases de Données
# 4                            J.CHEVALIER/M.LAGARRIGUE
# 6                          Salle I203  AUBRY à GONNET
# 7                               F008  GORVIEN à TELEP
# 8                                           ROBOTIQUE
# 9          Administration système et gestion de codes
# 12                                            F.JUMEL
# 13                                         Salle G103
# 14                                        08h30-11h30
# 15                           ELECTRONIQUE ET SYST EMB
# 16  Techniques avancées de conception des systèmes...
# 19                                        A. MASSOURI
# 20                         10h30 - 12h30 - Salle H001
# ...

# %%
# lecture modifier : on enleve les Nan rows
data[["MARDI"]].dropna(axis=0, how='any')
# Out:
#                                                 MARDI
# 0                                             28-févr
# 1                                            8h-12h15
# 2                          CONCEP.LOGICIELLE/BIG DATA
# 3                                    Bases de Données
# 4                            J.CHEVALIER/M.LAGARRIGUE
# 6                          Salle I203  AUBRY à GONNET
# 7                               F008  GORVIEN à TELEP
# 8                                           ROBOTIQUE
# 9          Administration système et gestion de codes
# 12                                            F.JUMEL
# 13                                         Salle G103
# 14                                        08h30-11h30
# 15                           ELECTRONIQUE ET SYST EMB
# 16  Techniques avancées de conception des systèmes...
# 19                                        A. MASSOURI
# 20                         10h30 - 12h30 - Salle H001
# ...
